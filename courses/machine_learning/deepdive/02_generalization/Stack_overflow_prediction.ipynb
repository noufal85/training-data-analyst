# %% [markdown]
# %%%%
# Let's say that you want to predict whether a Stackoverflow question will be acceptably answered. Using this public dataset of questions, create a machine learning dataset that you can use for classification.

# %%
import google.datalab.bigquery as bq
import seaborn as sns
import pandas as pd
import numpy as np
import shutil

# %%
query = """
SELECT * FROM `bigquery-public-data.stackoverflow.posts_questions` LIMIT 10
"""

# %%
sample = bq.Query(query).execute().result().to_dataframe()

# %%
sample.head()
# Out:
#          id                                              title  \
# 0  39479118   Memory leak caused by recycleview network image?
# 1  26432473  PayPal Classic API - Chained Delayed and PreAp...
# 2  45988257  Can someone detect error in this code to imple...
# 3   8170942  Firefox Addon - install.rdf - What does the "e...
# 4  37317634                        jButton HashMap count click
#
#                                                 body  accepted_answer_id  \
# 0  <p>I am using <strong>NetworkImageView</strong...                 NaN
# 1  <p>Using the PayPal Classic API (Java) for Ada...                 NaN
# 2  <p>I am trying to implement dijkstra's algorit...                 NaN
# 3  <p>What does the <code>em</code> mean in    </...           8171126.0
# 4  <p>Using the code from this <a href="https://s...          37318911.0
#
#    answer_count  comment_count community_owned_date           creation_date  \
# 0             0              2                 None 2016-09-13 21:17:17.927
# 1             0              2                 None 2014-10-17 19:50:53.753
# 2             1              0                 None 2017-08-31 18:51:39.573
# 3             1              0                 None 2011-11-17 16:44:34.137
# 4             1              2                 None 2016-05-19 08:18:32.093
#
#    favorite_count      last_activity_date          last_edit_date  \
# 0             NaN 2016-09-13 21:17:17.927                     NaT
# 1             NaN 2014-10-17 19:56:28.360 2014-10-17 19:56:28.360
# 2             NaN 2017-08-31 19:40:04.050                     NaT
# 3             NaN 2011-11-17 19:17:19.763 2011-11-17 19:17:19.763
# 4             NaN 2016-05-19 09:18:53.140 2017-05-23 11:44:04.873
#
#   last_editor_display_name  last_editor_user_id owner_display_name  \
# 0                                           NaN
# 1                                     1454048.0
# 2                                           NaN
# 3                                      592746.0
# 4                                          -1.0
#
#    owner_user_id  post_type_id  score  \
# 0      6802405.0             1      0
# 1      1401265.0             1      0
# 2      4664178.0             1      0
# 3       604383.0             1      4
# 4      5612454.0             1      0
#
#                                           tags  view_count
# 0  android|bitmap|android-bitmap|bitmapfactory          77
# 1                                       paypal         265
# 2      python|algorithm|shortest-path|dijkstra          44
# 3                    xml|firefox|firefox-addon         281
# 4                           java|swing|jbutton          60
